# %%
from scipy.io.arff import loadarff
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_arff = loadarff('D:/Python/jupyter/廖/Sapfile1.arff')
data_2 = pd.DataFrame(data_arff[0])

# %%
data_2.head()
# Out:
#      ge      cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'F'     b'G'  b'Good'  b'Good'  b'Vg'  b'Good'  b'Y'  b'Unmarried'  b'V'
# 1  b'M'   b'OBC'    b'Vg'    b'Vg'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
# 2  b'F'   b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 3  b'M'  b'MOBC'  b'Pass'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 4  b'M'     b'G'  b'Good'  b'Good'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
#
#         as  ...     fq     mq           fo            mo          nf  \
# 0  b'Paid'  ...  b'Um'  b'10'    b'Farmer'  b'Housewife'    b'Large'
# 1  b'Paid'  ...  b'Um'  b'Il'   b'Service'    b'Service'    b'Small'
# 2  b'Paid'  ...  b'12'  b'10'   b'Service'  b'Housewife'  b'Average'
# 3  b'Paid'  ...  b'12'  b'Um'  b'Business'   b'Business'    b'Large'
# 4  b'Paid'  ...  b'10'  b'12'   b'Service'  b'Housewife'    b'Large'
#
#            sh          ss      me          tt         atd
# ...

# %%
data_2.isnull().sum()
# No need to filter null.
# Out:
# ge     0
# cst    0
# tnp    0
# twp    0
# iap    0
# esp    0
# arr    0
# ms     0
# ls     0
# as     0
# fmi    0
# fs     0
# fq     0
# mq     0
# fo     0
# mo     0
# nf     0
# sh     0
# ss     0
# me     0
# tt     0
# atd    0
# dtype: int64

# %%
data_2.describe()
# Out:
#           ge     cst      tnp      twp    iap      esp   arr            ms  \
# count    131     131      131      131    131      131   131           131
# unique     2       5        4        4      4        4     2             1
# top     b'M'  b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'
# freq      72      57       59       65     63       54    78           131
#
#           ls       as  ...     fq     mq          fo            mo        nf  \
# count    131      131  ...    131    131         131           131       131
# unique     2        2  ...      6      6           5             5         3
# top     b'V'  b'Paid'  ...  b'Um'  b'Um'  b'Service'  b'Housewife'  b'Large'
# freq      92       76  ...     40     52          38           115        58
#
#                 sh       ss      me        tt      atd
# count          131      131     131       131      131
# unique           3        2       4         3        3
# ...

# %%
#####
def onehot_encode(data, var):
    encode = pd.get_dummies(raw[var])
    for label in raw[var].unique():
        data[f'{var}_{label}'] = encode[label]
    data.drop(var, axis = 1, inplace = True)

# %%
#### onehot encode
data = data_2.copy()
for var in data_2.columns:
    if type(data_2[var][0]) == str:
        onehot_encode(data, var)

# %%
data.head()
# Out:
#      ge      cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'F'     b'G'  b'Good'  b'Good'  b'Vg'  b'Good'  b'Y'  b'Unmarried'  b'V'
# 1  b'M'   b'OBC'    b'Vg'    b'Vg'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
# 2  b'F'   b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 3  b'M'  b'MOBC'  b'Pass'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 4  b'M'     b'G'  b'Good'  b'Good'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
#
#         as  ...     fq     mq           fo            mo          nf  \
# 0  b'Paid'  ...  b'Um'  b'10'    b'Farmer'  b'Housewife'    b'Large'
# 1  b'Paid'  ...  b'Um'  b'Il'   b'Service'    b'Service'    b'Small'
# 2  b'Paid'  ...  b'12'  b'10'   b'Service'  b'Housewife'  b'Average'
# 3  b'Paid'  ...  b'12'  b'Um'  b'Business'   b'Business'    b'Large'
# 4  b'Paid'  ...  b'10'  b'12'   b'Service'  b'Housewife'    b'Large'
#
#            sh          ss      me          tt         atd
# ...

# %%
from sklearn.preprocessing import LabelEncoder   #导入LabelEncoder模块

le = LabelEncoder()  #实例化对象
dfle = data
dfle['ge'] = le.fit_transform(dfle['ge']) #利用LabelEncoder将字段Car Model数字化
dfle['cst'] = le.fit_transform(dfle['cst']) 
dfle['tnp'] = le.fit_transform(dfle['tnp']) 
dfle['twp'] = le.fit_transform(dfle['twp']) 
dfle['iap'] = le.fit_transform(dfle['iap']) 
dfle['esp'] = le.fit_transform(dfle['esp']) 
dfle['arr'] = le.fit_transform(dfle['arr']) 
dfle['ms'] = le.fit_transform(dfle['ms']) 
dfle['ls'] = le.fit_transform(dfle['ls']) 
dfle['as'] = le.fit_transform(dfle['as']) 
dfle['fmi'] = le.fit_transform(dfle['fmi']) 
dfle['fs'] = le.fit_transform(dfle['fs']) 
dfle['fq'] = le.fit_transform(dfle['fq']) 
dfle['mq'] = le.fit_transform(dfle['mq']) 
dfle['fq'] = le.fit_transform(dfle['fq']) 
dfle['fo'] = le.fit_transform(dfle['fo']) 
dfle['mo'] = le.fit_transform(dfle['mo']) 
dfle['nf'] = le.fit_transform(dfle['nf']) 
dfle['sh'] = le.fit_transform(dfle['sh']) 
dfle['ss'] = le.fit_transform(dfle['ss']) 
dfle['me'] = le.fit_transform(dfle['me']) 
dfle['tt'] = le.fit_transform(dfle['tt']) 
dfle['atd'] = le.fit_transform(dfle['atd']) 
dfle
# Out:
#      ge  cst  tnp  twp  iap  esp  arr  ms  ls  as  ...  fq  mq  fo  mo  nf  \
# 0     0    0    1    1    3    1    1   0   1   1  ...   5   0   1   1   1
# 1     1    2    3    3    3    3    0   0   1   1  ...   5   3   4   4   2
# 2     0    2    1    1    3    1    0   0   1   1  ...   1   0   4   1   0
# 3     1    1    2    1    3    1    0   0   1   1  ...   1   5   0   0   1
# 4     1    0    1    1    3    3    0   0   1   1  ...   0   1   4   1   1
# ..   ..  ...  ...  ...  ...  ...  ...  ..  ..  ..  ...  ..  ..  ..  ..  ..
# 126   1    0    2    1    1    2    1   0   0   0  ...   5   3   4   1   2
# 127   1    1    3    3    1    1    0   0   1   0  ...   0   5   1   1   0
# 128   0    2    1    1    3    1    0   0   1   0  ...   3   3   1   1   2
# 129   1    4    2    2    1    2    1   0   1   0  ...   5   5   4   1   0
# 130   1    0    2    1    1    2    1   0   1   0  ...   5   5   0   1   0
#
#      sh  ss  me  tt  atd
# 0     2   0   0   2    1
# ...

# %%
data_2.columns
# Out:
# Index(['ge', 'cst', 'tnp', 'twp', 'iap', 'esp', 'arr', 'ms', 'ls', 'as', 'fmi',
#        'fs', 'fq', 'mq', 'fo', 'mo', 'nf', 'sh', 'ss', 'me', 'tt', 'atd'],
#       dtype='object')

# %%
x = dfle.iloc[:, 0:22]
x = x.drop(['esp'], axis = 1)
y = dfle['esp']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size = 0.25, random_state = 10)

# %%
#logistic
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import metrics

LR=LogisticRegression()
LR.fit(x_train,y_train)
LR_y_pred=LR.predict(x_test)

accuracy = metrics.accuracy_score(lrpred, y_test)
print ('Logistic_regression_result: \n', accuracy)
print('Coefficients: \n', LR.coef_)
print("Mean squared error: %.2f"% mean_squared_error(y_test, LR_y_pred))
print('Variance score: %.2f' % r2_score(y_test, LR_y_pred))
# Out:
# Logistic_regression_result:
#  0.6363636363636364
# Coefficients:
#  [[-2.56775820e-01 -5.02506698e-01  2.91157664e-01  2.32953137e-01
#   -1.04813900e+00 -8.11329925e-01  0.00000000e+00  1.83352011e-01
#    1.17532779e-01  2.37268590e-01  3.08330128e-01 -3.62887225e-01
#    2.41771464e-01 -2.08690629e-01  7.34384928e-01  4.63566025e-04
#   -4.61693028e-01  5.15507666e-01  7.21618675e-01  3.43938076e-01
#   -1.11436192e-01]
#  [-2.01110542e-01  1.91932881e-01 -4.06776176e-01 -4.17695019e-01
#    5.02580631e-01  1.06309095e-01  0.00000000e+00 -3.92491423e-01
#   -4.20126457e-01 -9.34888454e-02 -5.57258660e-01  1.40469399e-01
#   -1.54606722e-01 -9.33682819e-02 -1.41332471e-01 -2.31168418e-01
#    3.58928115e-01 -2.18452807e-01 -3.29096650e-02 -1.41678844e-01
#    1.65232172e-02]
#  [ 1.68997881e-01  8.37406727e-02 -3.31027082e-01 -1.04990175e-01
#   -7.40226601e-02  1.05223212e+00  0.00000000e+00 -6.53622243e-02
#   -3.55991862e-01 -1.10434118e-01  1.51082991e-02  2.25285473e-01
# ...

# %%
#logistic-graph
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import metrics

accuracy_rate = []
k_range = list(range(1, 30))
for k in k_range:
    LR=LogisticRegression()
    LR.fit(x_train,y_train)
    LR_y_pred=LR.predict(x_test)
    accuracy_rate.append(metrics.accuracy_score(LR_y_pred, y_test))
# Out:
# D:\Anaconda\ana\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# D:\Anaconda\ana\lib\site-packages\sklearn\linear_model\_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
plt.plot(k_range, accuracy_rate)
plt.xlabel('k_value')
plt.ylabel('Accuracy rate')
# Out:
# Text(0, 0.5, 'Accuracy rate')

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

accuracy_rate = []
k_range = list(range(1, 30))
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(x_train, y_train)
    kprediction = knn.predict(x_test)
    accuracy_rate.append(metrics.accuracy_score(kprediction, y_test))

# %%
plt.plot(k_range, accuracy_rate)
plt.xlabel('k_value')
plt.ylabel('Accuracy rate')
# Out:
# Text(0, 0.5, 'Accuracy rate')

# %%
#Decision tree
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier

dt_result = []
tree_depth = list(range(1, 40))
for depth in tree_depth:
    dt = DecisionTreeClassifier(random_state = 0, max_depth = depth)
    dt.fit(x_train,y_train)
    dtprediction = dt.predict(x_test)
    DT_result = metrics.accuracy_score(dtprediction,y_test)
    dt_result.append(DT_result)
    tree.plot_tree(dt) # Tree when depth is 30

# %%
plt.plot(tree_depth, dt_result)

# %%
#Here, when depth is about 4, it has good accuracy.

# %%
#RandomForest
from sklearn.ensemble import RandomForestClassifier


accuracy_rate = []
k_range = list(range(1, 40))
for k in k_range:
    rfr = RandomForestClassifier(n_estimators= j, max_features = "auto", oob_score = True, 
                        max_depth=k, random_state=50) ###Tree depth and tree numbers can be modified
    rfr.fit(x_train, y_train)
    y_pred=rfr.predict(x_test)
    accuracy_rate.append(metrics.accuracy_score(y_pred, y_test))

# %%
plt.plot(k_range, accuracy_rate)
plt.xlabel('k_value')
plt.ylabel('Accuracy rate')
# Out:
# Text(0, 0.5, 'Accuracy rate')

# %%
#SVM
from sklearn import svm

SVM=svm.SVR()
SVM.fit(x_train,y_train)
SVM_y_pred=SVM.predict(x_test)

print("Mean squared error: %.2f"% mean_squared_error(y_test, SVM_y_pred))
print('score: %.2f' % SVM.score(x_test,y_test))
# Out:
# Mean squared error: 1.08
# score: -0.05

# %%
accuracy_rate = []
k_range = list(range(1, 40))
for k in k_range:
    model = svm.SVC(C=j/10,kernel='rbf', gamma=k/10,   ###Cost and gamma can be modified
                decision_function_shape='ovr',random_state=0)   #ovr ovo
    model.fit(x_train, y_train) 
    y_pred=model.predict(x_test)
    accuracy_rate.append(metrics.accuracy_score(y_pred, y_test))

# %%
plt.plot(k_range, accuracy_rate)
plt.xlabel('k_value')
plt.ylabel('Accuracy rate')
# Out:
# Text(0, 0.5, 'Accuracy rate')

# %%
#choose k_value = 4

# %%
#Adaboost 
from sklearn.ensemble import AdaBoostClassifier

accuracy_rate = []
k_range = list(range(1, 70))
for k in k_range:
    clf = AdaBoostClassifier(n_estimators=k, random_state=0,learning_rate=0.8)
    clf.fit(x_train, y_train) 
    y_pred=clf.predict(x_test)
    accuracy_rate.append(metrics.accuracy_score(y_pred, y_test))

# %%
plt.plot(k_range, accuracy_rate)
plt.xlabel('k_value')
plt.ylabel('Accuracy rate')
# Out:
# Text(0, 0.5, 'Accuracy rate')
